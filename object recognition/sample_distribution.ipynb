# %%
from __future__ import print_function
from PIL import Image
import numpy as np
import h5py
import torch.utils.data as data
import os
import cv2
import random
import torchvision
import matplotlib.pyplot as plt
from torchvision import transforms as transforms

data = h5py.File('datasets/PET_MetaData_100.h5', 'r', driver='core')

train_labels = data['train_data_label'][:]
num0 = 0
num1 = 0
num2 = 0
num3 = 0
num4 = 0
num5 = 0
num6 = 0
num7 = 0
num8 = 0
num9 = 0
num10 = 0
num11 = 0
num12 = 0
num13 = 0
num14 = 0
num15 = 0
num16 = 0
num17 = 0
num18 = 0
num19 = 0
num20 = 0
num21 = 0
num22 = 0
num23 = 0
num24 = 0
num25 = 0
num26 = 0
num27 = 0
num28 = 0
num29 = 0
num30 = 0
num31 = 0
num32 = 0
num33 = 0
num34 = 0
num35 = 0
num36 = 0

for epoch in range(0, len(train_labels)):
    if train_labels[epoch] == 0:
        num0 = num0 + 1
    elif train_labels[epoch] == 1:
        num1 = num1 + 1
    elif train_labels[epoch] == 2:
        num2 = num2 + 1
    elif train_labels[epoch] == 3:
        num3 = num3 + 1
    elif train_labels[epoch] == 4:
        num4 = num4 + 1
    elif train_labels[epoch] == 5:
        num5 = num5 + 1
    elif train_labels[epoch] == 6:
        num6 = num6 + 1
    elif train_labels[epoch] == 7:
        num7 = num7 + 1
    elif train_labels[epoch] == 8:
        num8 = num8 + 1
    elif train_labels[epoch] == 9:
        num9 = num9 + 1
    elif train_labels[epoch] == 10:
        num10 = num10 + 1
    elif train_labels[epoch] == 11:
        num11 = num11 + 1
    elif train_labels[epoch] == 12:
        num12 = num12 + 1
    elif train_labels[epoch] == 13:
        num13 = num13 + 1
    elif train_labels[epoch] == 14:
        num14 = num14 + 1
    elif train_labels[epoch] == 15:
        num15 = num15 + 1
    elif train_labels[epoch] == 16:
        num16 = num16 + 1
    elif train_labels[epoch] == 17:
        num17 = num17 + 1
    elif train_labels[epoch] == 18:
        num18 = num18 + 1
    elif train_labels[epoch] == 19:
        num19 = num19 + 1
    elif train_labels[epoch] == 20:
        num20 = num20 + 1
    elif train_labels[epoch] == 21:
        num21 = num21 + 1
    elif train_labels[epoch] == 22:
        num22 = num22 + 1
    elif train_labels[epoch] == 23:
        num23 = num23 + 1
    elif train_labels[epoch] == 24:
        num24 = num24 + 1
    elif train_labels[epoch] == 25:
        num25 = num25 + 1
    elif train_labels[epoch] == 26:
        num26 = num26 + 1
    elif train_labels[epoch] == 27:
        num27 = num27 + 1
    elif train_labels[epoch] == 28:
        num28 = num28 + 1
    elif train_labels[epoch] == 29:
        num29 = num29 + 1
    elif train_labels[epoch] == 30:
        num30 = num30 + 1
    elif train_labels[epoch] == 31:
        num31 = num31 + 1
    elif train_labels[epoch] == 32:
        num32 = num32 + 1
    elif train_labels[epoch] == 33:
        num33 = num33 + 1
    elif train_labels[epoch] == 34:
        num34 = num34 + 1
    elif train_labels[epoch] == 35:
        num35 = num35 + 1
    elif train_labels[epoch] == 36:
        num36 = num36 + 1
    else:
        raise Exception('Invalid name of the teacher network...')
tran_num = [num0,num1,num2,num3,num4,num5,num6,num7,num8,num9,num10,num11,num12,num13,num14,num15,\
            num16,num17,num18,num19,num20,num21,num22,num23,num24,num25,num26,num27,num28,num29,\
            num30,num31,num32,num33,num34,num35,num36]
tran_num = np.array(tran_num)
print (tran_num)
print (tran_num.sum())














valid_labels = data['valid_data_label'][:]
num0 = 0
num1 = 0
num2 = 0
num3 = 0
num4 = 0
num5 = 0
num6 = 0
num7 = 0
num8 = 0
num9 = 0
num10 = 0
num11 = 0
num12 = 0
num13 = 0
num14 = 0
num15 = 0
num16 = 0
num17 = 0
num18 = 0
num19 = 0
num20 = 0
num21 = 0
num22 = 0
num23 = 0
num24 = 0
num25 = 0
num26 = 0
num27 = 0
num28 = 0
num29 = 0
num30 = 0
num31 = 0
num32 = 0
num33 = 0
num34 = 0
num35 = 0
num36 = 0

for epoch in range(0, len(valid_labels)):
    if valid_labels[epoch] == 0:
        num0 = num0 + 1
    elif valid_labels[epoch] == 1:
        num1 = num1 + 1
    elif valid_labels[epoch] == 2:
        num2 = num2 + 1
    elif valid_labels[epoch] == 3:
        num3 = num3 + 1
    elif valid_labels[epoch] == 4:
        num4 = num4 + 1
    elif valid_labels[epoch] == 5:
        num5 = num5 + 1
    elif valid_labels[epoch] == 6:
        num6 = num6 + 1
    elif valid_labels[epoch] == 7:
        num7 = num7 + 1
    elif valid_labels[epoch] == 8:
        num8 = num8 + 1
    elif valid_labels[epoch] == 9:
        num9 = num9 + 1
    elif valid_labels[epoch] == 10:
        num10 = num10 + 1
    elif valid_labels[epoch] == 11:
        num11 = num11 + 1
    elif valid_labels[epoch] == 12:
        num12 = num12 + 1
    elif valid_labels[epoch] == 13:
        num13 = num13 + 1
    elif valid_labels[epoch] == 14:
        num14 = num14 + 1
    elif valid_labels[epoch] == 15:
        num15 = num15 + 1
    elif valid_labels[epoch] == 16:
        num16 = num16 + 1
    elif valid_labels[epoch] == 17:
        num17 = num17 + 1
    elif valid_labels[epoch] == 18:
        num18 = num18 + 1
    elif valid_labels[epoch] == 19:
        num19 = num19 + 1
    elif valid_labels[epoch] == 20:
        num20 = num20 + 1
    elif valid_labels[epoch] == 21:
        num21 = num21 + 1
    elif valid_labels[epoch] == 22:
        num22 = num22 + 1
    elif valid_labels[epoch] == 23:
        num23 = num23 + 1
    elif valid_labels[epoch] == 24:
        num24 = num24 + 1
    elif valid_labels[epoch] == 25:
        num25 = num25 + 1
    elif valid_labels[epoch] == 26:
        num26 = num26 + 1
    elif valid_labels[epoch] == 27:
        num27 = num27 + 1
    elif valid_labels[epoch] == 28:
        num28 = num28 + 1
    elif valid_labels[epoch] == 29:
        num29 = num29 + 1
    elif valid_labels[epoch] == 30:
        num30 = num30 + 1
    elif valid_labels[epoch] == 31:
        num31 = num31 + 1
    elif valid_labels[epoch] == 32:
        num32 = num32 + 1
    elif valid_labels[epoch] == 33:
        num33 = num33 + 1
    elif valid_labels[epoch] == 34:
        num34 = num34 + 1
    elif valid_labels[epoch] == 35:
        num35 = num35 + 1
    elif valid_labels[epoch] == 36:
        num36 = num36 + 1
    else:
        raise Exception('Invalid name of the teacher network...')
valid_num = [num0,num1,num2,num3,num4,num5,num6,num7,num8,num9,num10,num11,num12,num13,num14,num15,\
            num16,num17,num18,num19,num20,num21,num22,num23,num24,num25,num26,num27,num28,num29,\
            num30,num31,num32,num33,num34,num35,num36]
valid_num = np.array(valid_num)
print (valid_num)
print (valid_num.sum())



















PrivateTest_labels = data['test_data_label'][:]
num = 0
c = 0 
test_num = [0 for i in range(37)]
for epoch in range(0, len(PrivateTest_labels)):
    if PrivateTest_labels[epoch] == c:
        num = num + 1
    else:
        test_num[c] = num
        num = 1
        c = c + 1
test_num[36] = num
test_num = np.array(test_num)
print (test_num)
print (test_num.sum())

epochs = range(0,37)
plt.figure(figsize=(20, 5))
plt.tick_params(labelsize=15)
plt.bar(epochs,test_num,color="#B22222",bottom=np.array(valid_num+tran_num),label="data distribution of testing samples")
plt.bar(epochs,valid_num,color="#1E90FF",bottom=np.array(tran_num),label="data distribution of validation samples")
plt.bar(epochs,tran_num,color="b",label="data distribution of training samples")
plt.xlabel(r'category', fontsize=15)
plt.ylabel('amount', fontsize=15)
plt.legend(bbox_to_anchor=(0, 1.05), loc=3, borderaxespad=0, fontsize=15)
plt.subplots_adjust(bottom=0.30)
if not os.path.isdir('picture/'):
    os.mkdir('picture/')
plt.savefig('picture/PET.jpg', dpi=500, bbox_inches = 'tight')
plt.show()
# Out:
# [74 74 74 74 74 74 74 71 74 74 74 69 71 74 74 74 74 74 74 74 74 74 71 74
#  74 74 74 74 74 74 74 74 74 74 74 74 74]
# 2724
# [26 26 26 26 26 26 26 25 26 26 26 24 25 26 26 26 26 26 26 26 26 26 25 26
#  26 26 26 26 26 26 26 26 25 26 26 26 26]
# 956
# [ 98 100 100 100 100 100 100  88  99 100 100  97 100 100 100 100 100 100
#   99 100 100 100 100 100 100 100 100 100 100 100  99 100 100 100  89 100
#  100]
# 3669
